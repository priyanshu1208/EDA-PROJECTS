# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
import matplotlib 
matplotlib.rcParams['figure.figsize']=(12,6)

# %%
df = pd.read_csv(r"C:\Users\dell\Desktop\Laptop_Information.csv")
df.head()
# Out:
#    Unnamed: 0 Company  Rating  No_of_ratings  Review  Size  \
# 0           0      HP     4.2            253      20  36.0
# 1           1  Lenovo     4.2            974      75  36.0
# 2           2    ASUS     4.4           5389     535  40.0
# 3           3    DELL     4.1            332      26  40.0
# 4           4    ASUS     4.2            487      53  40.0
#
#                                            Processor  RAM  \
# 0                    AMD Ryzen 5 Hexa Core Processor   16
# 1                 Intel Core i3 Processor (11th Gen)    8
# 2                 Intel Core i5 Processor (10th Gen)    8
# 3  Processor: Intel i3-1115G4 (Base- 1.7 GHz & Tu...    8
# 4                 Intel Core i3 Processor (11th Gen)    8
#
#                                     Memory  \
# 0                               512 GB SSD
# 1                               256 GB SSD
# 2                               512 GB SSD
# 3  Display: 15.6" FHD WVA AG Narrow Border
# ...

# %%
df.shape
# Out:
# (984, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984 entries, 0 to 983
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     984 non-null    int64
#  1   Company        984 non-null    object
#  2   Rating         984 non-null    float64
#  3   No_of_ratings  984 non-null    int64
#  4   Review         984 non-null    int64
#  5   Size           984 non-null    float64
#  6   Processor      984 non-null    object
#  7   RAM            984 non-null    int64
#  8   Memory         984 non-null    object
#  9   OpSys          984 non-null    object
#  10  Price          984 non-null    int64
#  11  MRP            984 non-null    int64
#  12  ImgURL         984 non-null    object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 100.1+ KB

# %%
df = df.drop('Unnamed: 0',axis = 1)

# %%
df.head()
# Out:
#   Company  Rating  No_of_ratings  Review  Size  \
# 0      HP     4.2            253      20  36.0
# 1  Lenovo     4.2            974      75  36.0
# 2    ASUS     4.4           5389     535  40.0
# 3    DELL     4.1            332      26  40.0
# 4    ASUS     4.2            487      53  40.0
#
#                                            Processor  RAM  \
# 0                    AMD Ryzen 5 Hexa Core Processor   16
# 1                 Intel Core i3 Processor (11th Gen)    8
# 2                 Intel Core i5 Processor (10th Gen)    8
# 3  Processor: Intel i3-1115G4 (Base- 1.7 GHz & Tu...    8
# 4                 Intel Core i3 Processor (11th Gen)    8
#
#                                     Memory  \
# 0                               512 GB SSD
# 1                               256 GB SSD
# 2                               512 GB SSD
# 3  Display: 15.6" FHD WVA AG Narrow Border
# 4                               512 GB SSD
#
# ...

# %%
df.isnull().sum()
# Out:
# Company          0
# Rating           0
# No_of_ratings    0
# Review           0
# Size             0
# Processor        0
# RAM              0
# Memory           0
# OpSys            0
# Price            0
# MRP              0
# ImgURL           0
# dtype: int64

# %%
cval = df['Company'].value_counts().values
cval
# Out:
# array([284, 206, 161, 129,  57,  54,  35,  28,   6,   4,   4,   3,   3,
#          2,   2,   2,   2,   1,   1], dtype=int64)

# %%
cname = df['Company'].value_counts().index
cname
# Out:
# Index(['Lenovo', 'ASUS', 'HP', 'DELL', 'acer', 'MSI', 'APPLE', 'Infinix',
#        'SAMSUNG', 'realme', 'ALIENWARE', 'GIGABYTE', 'Vaio', 'RedmiBook',
#        'Avita', 'Nokia', 'LG', 'Mi', 'Primebook'],
#       dtype='object')

# %%
plt.pie(cval[:8],labels = cname[:8],autopct = '%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1c618c02c70>,
# ...
#  [Text(0.6529940369070514, 0.8852111543376714, 'Lenovo'),
#   Text(-0.9123462198000607, 0.6145114931525198, 'ASUS'),
#   Text(-0.897939725090218, -0.6353772502261187, 'HP'),
#   Text(-5.149471704824549e-08, -1.0999999999999988, 'DELL'),
#   Text(0.6324168166868787, -0.9000272051286201, 'acer'),
#   Text(0.9123462198000607, -0.6145114931525198, 'MSI'),
#   Text(1.0509774221706676, -0.32472520396097737, 'APPLE'),
#   Text(1.0953272290207186, -0.10128307541635162, 'Infinix')],
#  [Text(0.35617856558566435, 0.48284244782054797, '29.77%'),
#   Text(-0.4976433926182149, 0.3351880871741017, '21.59%'),
#   Text(-0.4897853045946643, -0.34656940921424656, '16.88%'),
#   Text(-2.8088027480861175e-08, -0.5999999999999993, '13.52%'),
#   Text(0.3449546272837519, -0.4909239300701564, '5.97%'),
#   Text(0.4976433926182149, -0.3351880871741017, '5.66%'),
#   Text(0.5732604120930914, -0.17712283852416946, '3.67%'),
# ...

# %%
df = df.drop('Processor',axis =1)

# %%
df.head()
# Out:
#   Company  Rating  No_of_ratings  Review  Size  RAM  \
# 0      HP     4.2            253      20  36.0   16
# 1  Lenovo     4.2            974      75  36.0    8
# 2    ASUS     4.4           5389     535  40.0    8
# 3    DELL     4.1            332      26  40.0    8
# 4    ASUS     4.2            487      53  40.0    8
#
#                                     Memory  \
# 0                               512 GB SSD
# 1                               256 GB SSD
# 2                               512 GB SSD
# 3  Display: 15.6" FHD WVA AG Narrow Border
# 4                               512 GB SSD
#
#                                                OpSys  Price    MRP  \
# 0                                 64 bit Windows 11   49990  59240
# 1                                 64 bit Windows 11   33990  60890
# 2                                        Windows 11   49990  70990
# 3  Graphics & Keyboard: Integrated & Standard Key...  37990  58489
# ...

# %%
df['RAM'].unique()
# Out:
# array([16,  8,  4, 32], dtype=int64)

# %%
df['LSize'] = df['Memory'].value_counts().reset_index().iloc[:,1]

# %%
df.head()
# Out:
#   Company  Rating  No_of_ratings  Review  Size  RAM  \
# 0      HP     4.2            253      20  36.0   16
# 1  Lenovo     4.2            974      75  36.0    8
# 2    ASUS     4.4           5389     535  40.0    8
# 3    DELL     4.1            332      26  40.0    8
# 4    ASUS     4.2            487      53  40.0    8
#
#                                     Memory  \
# 0                               512 GB SSD
# 1                               256 GB SSD
# 2                               512 GB SSD
# 3  Display: 15.6" FHD WVA AG Narrow Border
# 4                               512 GB SSD
#
#                                                OpSys  Price    MRP  \
# 0                                 64 bit Windows 11   49990  59240
# 1                                 64 bit Windows 11   33990  60890
# 2                                        Windows 11   49990  70990
# 3  Graphics & Keyboard: Integrated & Standard Key...  37990  58489
# ...

# %%
name = df['Company'].value_counts().index[:5]
name
# Out:
# Index(['Lenovo', 'ASUS', 'HP', 'DELL', 'acer'], dtype='object')

# %%
df['Rating'].groupby(df['Company']).size().index
# Out:
# Index(['ALIENWARE', 'APPLE', 'ASUS', 'Avita', 'DELL', 'GIGABYTE', 'HP',
#        'Infinix', 'LG', 'Lenovo', 'MSI', 'Mi', 'Nokia', 'Primebook',
#        'RedmiBook', 'SAMSUNG', 'Vaio', 'acer', 'realme'],
#       dtype='object', name='Company')

# %%
sns.barplot('Company','Rating',data = df)
# Out:
# <AxesSubplot:xlabel='Company', ylabel='Rating'>

# %%
sns.barplot('Company','No_of_ratings',data = df)
# Out:
# <AxesSubplot:xlabel='Company', ylabel='No_of_ratings'>

# %%
sns.countplot('Company',data =df)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19920\1431215138.py in <module>
# ----> 1 sns.countplot('Company',data =df)[:5]
#
# TypeError: 'AxesSubplot' object is not subscriptable

# %%
sns.pairplot(df)

# %%
sns.barplot("Size","Price",data = df)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Size', ylabel='Price'>

# %%
sns.boxplot("Size","Price",data = df)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Size', ylabel='Price'>

# %%
sns.scatterplot('MRP',"Price",data = df)
# Out:
# C:\Users\dell\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='MRP', ylabel='Price'>
